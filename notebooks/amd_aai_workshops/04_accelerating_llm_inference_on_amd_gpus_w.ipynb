# %% [markdown]
# # AMD AAI Workshop 04: Accelerating LLM Inference on AMD GPUs with AMD ATOM
#
# **AMD ATOM on MI300X**
#
# **Project Integration for UnicornForge AI:** Use AMD ATOM to accelerate inference of the local model used for generating structured startup briefs in UnicornForge.
#
# Hardware: AMD GPUs (MI300X or Radeon as noted)
#
# This notebook prepares the workshop for use in the UnicornForge AI hackathon project.

# %% [markdown]
# ## Environment Setup
#
# Make sure you are on a system with the appropriate AMD ROCm setup (see project Dockerfile.rocm).

# %%
import torch
import os

print('PyTorch:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('Device:', torch.cuda.get_device_name(0))
    print('ROCm/HIP visible devices:', os.environ.get('ROCR_VISIBLE_DEVICES', 'all'))

# %% [markdown]
# ## Workshop Steps
#
# Follow the official AMD AAI Workshop instructions for this session.
#
# Below are project-specific adaptations and starting code.

# %%
# Using AMD ATOM for optimized inference
import atom  # AMD ATOM lib
# atom.optimize(model)
# Faster generation for /generate-brief endpoint
print("AMD ATOM accelerated inference ready")

# %% [markdown]
# ## Integration with UnicornForge
#
# - How this tech improves brief generation or success scoring.
# - Next steps: integrate into backend/services or ml/ modules.
# - Run experiments and log results for hackathon demo/video.

# %%
# Example: tie back to project
print('Notebook ready for UnicornForge + AMD Workshop integration.')
